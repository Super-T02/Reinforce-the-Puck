# %% [markdown]
# # Try around with the tournament logic

# %%
from openskill.models import PlackettLuce

model = PlackettLuce()

# %%
p1 = model.rating(name="john123")
print(p1)
# Out:
# Plackett-Luce Player Data:
#
# id: d7ac3f73df4a4258bc2960044e7fdee6
# name: john123
# mu: 25.0
# sigma: 8.333333333333334

# %%
p2 = model.rating(name="jane234")
p3 = model.rating(name="joe546")
p4 = model.rating(name="jill678")

# %%
team1 = [p1, p2]
team2 = [p3, p4]

# %%
match = [team1, team2]
[team1, team2] = model.rate(match)
[p1, p2] = team1
[p3, p4] = team2

for player in [p1, p2, p3, p4]:
    print(player)
# Out:
# Plackett-Luce Player Data:
#
# id: d7ac3f73df4a4258bc2960044e7fdee6
# name: john123
# mu: 28.460463022176633
# sigma: 8.034052272022798
#
# Plackett-Luce Player Data:
#
# id: ca8fe3cc20774d058d46cfba3d52f769
# name: jane234
# mu: 28.460463022176633
# sigma: 8.034052272022798
#
# Plackett-Luce Player Data:
#
# id: 53be72f604b9440aab164f69509c0a0f
# name: joe546
# mu: 21.539536977823367
# sigma: 8.034052272022798
#
# Plackett-Luce Player Data:
#
# id: ea45f72fa9764c86baa7d731f857e9a0
# name: jill678
# mu: 21.539536977823367
# sigma: 8.034052272022798
